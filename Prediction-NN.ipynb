# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from keras.wrappers.scikit_learn import KerasClassifier
pd.set_option('display.max_columns', None)
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm
# Out:
# In /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
data = pd.read_csv('outlier_remove.csv')

# %%
data
# Out:
#                            id                     song             album  \
# 0      1mTxphc9naXMLE9qfMkEVh                      NaN               NaN
# 1      2Tp1yCGNjjZ39HTEnKaqhx                      NaN               NaN
# 2      3plzStfrkTOq9lehqqI3bG                      NaN               NaN
# 3      2MGhUOnAifh3znlInWnywc                      NaN               NaN
# 4      1vDRvO1X021HlJY2NnqUU2                      NaN               NaN
# ...                       ...                      ...               ...
# 66447  6h2t5HKOpHjpou4cHA5OER                    Cocky             Cocky
# 66448  6h3YJ05BovN1Pgk145J3r9               Mama Tried    I Am What I Am
# 66449  6h5w4ez470ZaXq6sD2FozJ  Didn't Know It Was Love  Too Hot To Sleep
# 66450  6h77X5H4dP9l2jzG92vVv0    The Alternative Polka      Bad Hair Day
# 66451  6h8laPks98zPizQ5qahy40               Winterlude       New Morning
#
#                     artist  acousticness_x  danceability_x  duration_ms_x  \
# 0                      NaN             NaN             NaN            NaN
# 1                      NaN             NaN             NaN            NaN
# 2                      NaN             NaN             NaN            NaN
# 3                      NaN             NaN             NaN            NaN
# 4                      NaN             NaN             NaN            NaN
# ...                    ...             ...             ...            ...
# 66447             Kid Rock          0.1610           0.617       237507.0
# 66448        Merle Haggard          0.7190           0.738       134453.0
# 66449             Survivor          0.1220           0.613       262800.0
# 66450  "Weird Al" Yankovic          0.0914           0.393       290907.0
# 66451            Bob Dylan          0.9100           0.329       142947.0
#
#        energy_x  instrumentalness_x  key_x  liveness_x  loudness_x  mode_x  \
# 0           NaN                 NaN    NaN         NaN         NaN     NaN
# 1           NaN                 NaN    NaN         NaN         NaN     NaN
# 2           NaN                 NaN    NaN         NaN         NaN     NaN
# 3           NaN                 NaN    NaN         NaN         NaN     NaN
# 4           NaN                 NaN    NaN         NaN         NaN     NaN
# ...         ...                 ...    ...         ...         ...     ...
# 66447     0.921            0.000000    9.0      0.0887      -3.200     1.0
# 66448     0.538            0.000013    2.0      0.0653     -10.118     1.0
# 66449     0.683            0.000000    2.0      0.2410     -11.156     1.0
# 66450     0.878            0.000000    4.0      0.3190      -7.519     0.0
# 66451     0.389            0.013100    0.0      0.1140     -12.425     1.0
#
#        speechiness_x  tempo_x  time_signature  valence_x  \
# 0                NaN      NaN             NaN        NaN
# 1                NaN      NaN             NaN        NaN
# 2                NaN      NaN             NaN        NaN
# 3                NaN      NaN             NaN        NaN
# 4                NaN      NaN             NaN        NaN
# ...              ...      ...             ...        ...
# 66447         0.1790  184.028             4.0      0.688
# 66448         0.0374   97.487             4.0      0.810
# 66449         0.0332  128.416             4.0      0.637
# 66450         0.0558  176.646             4.0      0.898
# 66451         0.0384   50.166             4.0      0.492
#
#                      album_id        date  date_year  duration_ms_d  \
# 0                         NaN         NaN        NaN            NaN
# 1                         NaN         NaN        NaN            NaN
# 2                         NaN         NaN        NaN            NaN
# 3                         NaN         NaN        NaN            NaN
# 4                         NaN         NaN        NaN            NaN
# ...                       ...         ...        ...            ...
# 66447  64du8CiAmKAzVswhA3RK4r  2001-11-19     2001.0       237507.0
# 66448  7LmhShcQUdQf0vbfa6VUPn  2006-01-01     2006.0       134453.0
# 66449  1vDCPR1K9O81nzU2bRWYNE        1988     1988.0       262800.0
# 66450  0Jlz2oUJcRROhY8MFMp609  1996-12-31     1996.0       290907.0
# 66451  48efaobqOTbvnlxbETstey  1970-10-21     1970.0       142947.0
#
#                                                  com_f_x  acousticness_y  \
# 0                                                    NaN          0.0309
# 1                                                    NaN          0.9760
# 2                                                    NaN          0.3660
# 3                                                    NaN          0.9260
# 4                                                    NaN          0.9620
# ...                                                  ...             ...
# 66447  Kid Rock237507Cocky0.1610.6170.920999999999999...          0.1610
# 66448  Merle Haggard134453Mama Tried0.719000000000000...          0.7190
# 66449  Survivor262800Didn't Know It Was Love0.1220.61...          0.1220
# 66450  "Weird Al" Yankovic290907The Alternative Polka...          0.0914
# 66451  Bob Dylan142947Winterlude0.910.328999999999999...          0.9100
#
#                                artists  danceability_y  duration_ms_y  \
# 0      ['The Cotton Candy Blues Band']           0.593         187286
# 1                     ['The Keynotes']           0.369         103333
# 2                              ['EOR']           0.631         324882
# 3                    ['Lowell Fulson']           0.670         170333
# 4           ['Sonny Boy Williamson I']           0.572         186227
# ...                                ...             ...            ...
# 66447                     ['Kid Rock']           0.617         237507
# 66448                ['Merle Haggard']           0.738         134453
# 66449                     ['Survivor']           0.613         262800
# 66450          ['"Weird Al" Yankovic']           0.393         290907
# 66451                    ['Bob Dylan']           0.329         142947
#
#        energy_y  explicit  instrumentalness_y  key_y  liveness_y  loudness_y  \
# 0         0.450         0            0.001870      2      0.3340     -10.679
# 1         0.228         0            0.000000      1      0.1500      -9.628
# 2         0.682         0            0.000000      9      0.3380     -10.486
# 3         0.351         0            0.005310      0      0.1680      -5.714
# 4         0.164         0            0.003460      0      0.2470     -15.842
# ...         ...       ...                 ...    ...         ...         ...
# 66447     0.921         1            0.000000      9      0.0887      -3.200
# 66448     0.538         0            0.000013      2      0.0653     -10.118
# 66449     0.683         0            0.000000      2      0.2410     -11.156
# 66450     0.878         0            0.000000      4      0.3190      -7.519
# 66451     0.389         0            0.013100      0      0.1140     -12.425
#
#        mode_y                     name  popularity release_date  \
# 0           1     Early in the morning           0         1940
# 1           1             I Don't Know           0         1945
# 2           0                     Till           0         1946
# 3           1             Fulson Blues           0         1945
# 4           1               Down South           0         1945
# ...       ...                      ...         ...          ...
# 66447       1                    Cocky          55   2001-11-19
# 66448       1               Mama Tried          57   2006-01-01
# 66449       1  Didn't Know It Was Love          34   1988-09-25
# 66450       0    The Alternative Polka          35   1996-12-31
# 66451       1               Winterlude          39   1970-10-21
#
#        speechiness_y  tempo_y  valence_y  year release_date_year  \
# 0             0.0307  112.054      0.454  1940        1940-01-01
# 1             0.0300   82.394      0.572  1945        1945-01-01
# 2             0.0417  150.061      0.386  1946        1946-01-01
# 3             0.0693  140.253      0.580  1945        1945-01-01
# 4             0.0471   78.439      0.661  1945        1945-01-01
# ...              ...      ...        ...   ...               ...
# 66447         0.1790  184.028      0.688  2001        2001-01-01
# 66448         0.0374   97.487      0.810  2006        2006-01-01
# 66449         0.0332  128.416      0.637  1988        1988-01-01
# 66450         0.0558  176.646      0.898  1996        1996-01-01
# 66451         0.0384   50.166      0.492  1970        1970-01-01
#
#                          artists_d  \
# 0      The Cotton Candy Blues Band
# 1                     The Keynotes
# 2                              EOR
# 3                    Lowell Fulson
# 4           Sonny Boy Williamson I
# ...                            ...
# 66447                     Kid Rock
# 66448                Merle Haggard
# 66449                     Survivor
# 66450          "Weird Al" Yankovic
# 66451                    Bob Dylan
#
#                                                  com_f_y  popularity_dummy  \
# 0      The Cotton Candy Blues Band187286Early in the ...                 0
# 1      The Keynotes103333I Don't Know0.9760.3690.2280...                 0
# 2      EOR324882Till0.3660.6310.68200.090.338-10.4860...                 0
# 3      Lowell Fulson170333Fulson Blues0.9260.670.3510...                 0
# 4      Sonny Boy Williamson I186227Down South0.9620.5...                 0
# ...                                                  ...               ...
# 66447  Kid Rock237507Cocky0.1610.6170.92110.090.0887-...                 1
# 66448  Merle Haggard134453Mama Tried0.719000000000000...                 1
# 66449  Survivor262800Didn't Know It Was Love0.1220.61...                 1
# 66450  "Weird Al" Yankovic290907The Alternative Polka...                 1
# 66451  Bob Dylan142947Winterlude0.910.3290.38900.0131...                 1
#
#                                                   lyrics  \
# 0      money on the table , i ain ' tryna play with y...
# 1      i don ' know why i love you like i do oh , my ...
# 2      hook : i ' just tryna be my own man , my own m...
# 3      i ain ' heard your voice in such as long time ...
# 4      hobo blues 3 : 22 trk yank rachel - vocal & gu...
# ...                                                  ...
# 66447  guess who ' back i used to be broke , confused...
# 66448  the first thing i remember knowing was a lones...
# 66449  it felt so easy in the morning sun when love w...
# 66450  soy un perdedor ! i ' a loser , baby ! so why ...
# 66451  winterlude , winterlude , oh darling winterlud...
#
#                                         stats_dict_tuple  num_sentences  \
# 0      ({'num_sentences': 6, 'num_words': 783, 'num_s...            6.0
# 1      ({'num_sentences': 4, 'num_words': 186, 'num_s...            4.0
# 2      ({'num_sentences': 6, 'num_words': 495, 'num_s...            6.0
# 3      ({'num_sentences': 1, 'num_words': 183, 'num_s...            1.0
# 4      ({'num_sentences': 8, 'num_words': 486, 'num_s...            8.0
# ...                                                  ...            ...
# 66447  ({'num_sentences': 5, 'num_words': 528, 'num_s...            5.0
# 66448  ({'num_sentences': 1, 'num_words': 218, 'num_s...            1.0
# 66449  ({'num_sentences': 1, 'num_words': 221, 'num_s...            1.0
# 66450  ({'num_sentences': 23, 'num_words': 645, 'num_...           23.0
# 66451  ({'num_sentences': 1, 'num_words': 195, 'num_s...            1.0
#
#        num_words  num_syllables  readability             grade  richness  \
# 0          783.0          735.0       -5.036  College Graduate  0.177977
# 1          186.0          152.0       90.502         5th Grade  0.076503
# 2          495.0          527.0       33.028     College Level  0.254582
# 3          183.0          179.0      -61.661  College Graduate  0.191257
# 4          486.0          434.0       69.626         9th Grade  0.200000
# ...          ...            ...          ...               ...       ...
# 66447      528.0          586.0        5.758  College Graduate  0.282443
# 66448      218.0          264.0     -116.886  College Graduate  0.298165
# 66449      221.0          221.0     -102.080  College Graduate  0.325792
# 66450      645.0          641.0       94.296         5th Grade  0.142857
# 66451      195.0          230.0      -90.875  College Graduate  0.387755
#
#       Language    neg    neu    pos  compound  compound_vader_polarity  \
# 0           en  0.102  0.846  0.052   -0.9857                     -1.0
# 1           en  0.294  0.455  0.251   -0.8895                     -1.0
# 2           en  0.064  0.800  0.136    0.9856                      1.0
# 3           en  0.109  0.817  0.074   -0.5831                     -1.0
# 4           en  0.034  0.913  0.053    0.6788                      1.0
# ...        ...    ...    ...    ...       ...                      ...
# 66447       en  0.108  0.780  0.112    0.9189                      1.0
# 66448       en  0.160  0.737  0.103   -0.9280                     -1.0
# 66449       en  0.108  0.728  0.164    0.9471                      1.0
# 66450       en  0.116  0.777  0.107    0.6269                      1.0
# 66451       en  0.062  0.802  0.137    0.9253                      1.0
#
#        artist_popularity
# 0               0.000000
# 1               5.000000
# 2              46.000000
# 3              38.000000
# 4              60.848402
# ...                  ...
# 66447          72.000000
# 66448          65.000000
# 66449          72.000000
# 66450          61.000000
# 66451          78.000000
#
# [66452 rows x 59 columns]

# %%
acoustic_col= ['acousticness_y','danceability_y','duration_ms_y','energy_y','explicit','instrumentalness_y','key_y',
       'liveness_y','loudness_y','mode_y','speechiness_y','tempo_y','valence_y']
lyrics_col = ['num_words','num_syllables','readability','richness','compound','artist_popularity']

# %%
df = data [acoustic_col+lyrics_col+['popularity']]

# %%
df.shape
# Out:
# (66452, 20)

# %%
#sns.distplot(df['popularity'],color='g')

# %%
y = df['popularity'].copy()
X=df[acoustic_col+lyrics_col].copy()

# %%
X.shape
# Out:
# (66452, 19)

# %%
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers.normalization import BatchNormalization

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y,train_size=0.8,random_state=1234)

# %%
scale_features= X.drop(['explicit','mode_y'],axis=1).columns

# %%
scaler = StandardScaler()
scaler.fit(X_train[scale_features])
X_train[scale_features]= scaler.transform(X_train[scale_features])
X_test[scale_features]= scaler.transform(X_test[scale_features])

# %%
input_nodes = X_train.shape[1]
output_nodes = 1

# %%
model = Sequential()
model.add(Input((input_nodes,)))
model.add(Dense(256, activation="relu"))
# model.add(Dropout(0.3, seed=0))
model.add(Dense(256, activation="relu"))
# model.add(Dropout(0.3, seed=1))
model.add(Dense(256, activation="relu"))
# model.add(Dropout(0.3, seed=2))
model.add(Dense(output_nodes, activation="linear"))

optimizer = keras.optimizers.Adam(lr=0.001)

model.compile(optimizer=optimizer,loss='mean_squared_error',metrics=['mean_squared_error'])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               5120
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 136,961
# Trainable params: 136,961
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
X_train = np.asarray(X_train).astype(np.float32)

# %%
history = model.fit(X_train,
        y_train,
        batch_size=128,
        epochs=15,
        verbose=1,
        )
# Out:
# Epoch 1/15
# 416/416 [==============================] - 1s 2ms/step - loss: 282.0994 - mean_squared_error: 282.0994
# Epoch 2/15
# 416/416 [==============================] - 1s 1ms/step - loss: 192.1465 - mean_squared_error: 192.1465
# Epoch 3/15
# 416/416 [==============================] - 1s 1ms/step - loss: 184.7247 - mean_squared_error: 184.7247
# Epoch 4/15
# 416/416 [==============================] - 1s 1ms/step - loss: 180.8299 - mean_squared_error: 180.8299
# Epoch 5/15
# 416/416 [==============================] - 1s 1ms/step - loss: 178.5840 - mean_squared_error: 178.5840
# Epoch 6/15
# 416/416 [==============================] - 1s 2ms/step - loss: 177.3492 - mean_squared_error: 177.3492
# Epoch 7/15
# 416/416 [==============================] - 1s 2ms/step - loss: 175.6944 - mean_squared_error: 175.6944
# Epoch 8/15
# 416/416 [==============================] - 1s 2ms/step - loss: 173.1383 - mean_squared_error: 173.1383
# Epoch 9/15
# 416/416 [==============================] - 1s 2ms/step - loss: 171.8948 - mean_squared_error: 171.8948
# Epoch 10/15
# 416/416 [==============================] - 1s 2ms/step - loss: 170.9245 - mean_squared_error: 170.9245
# Epoch 11/15
# 416/416 [==============================] - 1s 2ms/step - loss: 169.1759 - mean_squared_error: 169.1759
# Epoch 12/15
# 416/416 [==============================] - 1s 2ms/step - loss: 167.9540 - mean_squared_error: 167.9540
# Epoch 13/15
# 416/416 [==============================] - 1s 2ms/step - loss: 166.8161 - mean_squared_error: 166.8161
# Epoch 14/15
# 416/416 [==============================] - 1s 2ms/step - loss: 165.6479 - mean_squared_error: 165.6479
# Epoch 15/15
# 416/416 [==============================] - 1s 2ms/step - loss: 164.8603 - mean_squared_error: 164.8603

# %%
plt.plot(history.history['mean_squared_error'],color = 'g')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = math.sqrt(mean_squared_error(y_test, y_pred))
print("MAE:",mae)
print("RMSE:",rmse)
# Out:
# MAE: 10.574926298536312
# RMSE: 13.383873646517705

# %%
def NN():
    model = Sequential()
    model.add(Input((input_nodes,)))
    model.add(Dense(256, activation="relu"))
    # model.add(Dropout(0.3, seed=0))
    model.add(Dense(256, activation="relu"))
    # model.add(Dropout(0.3, seed=1))
    model.add(Dense(256, activation="relu"))
    # model.add(Dropout(0.3, seed=2))
    model.add(Dense(output_nodes, activation="linear"))

    optimizer = keras.optimizers.Adam(lr=0.001)

    model.compile(optimizer=optimizer,loss='mean_squared_error',metrics=['mean_squared_error'])
    return model

clf=KerasClassifier(build_fn=NN, verbose=1)
batch_size = [32, 64, 128, 256]
epochs = [10,11,12,13,14,15,16]
search_spaces=dict(batch_size=batch_size,epochs=epochs,lr= lr)

# %%
def NeuN(lr):
    model = Sequential()
    model.add(Input((input_nodes,)))
    model.add(Dense(256, activation="relu"))
    # model.add(Dropout(0.3, seed=0))
    model.add(Dense(256, activation="relu"))
    # model.add(Dropout(0.3, seed=1))
    model.add(Dense(256, activation="relu"))
    # model.add(Dropout(0.3, seed=2))
    model.add(Dense(output_nodes, activation="linear"))

    optimizer = keras.optimizers.Adam(lr=lr)

    model.compile(optimizer=optimizer,loss='mean_squared_error',metrics=['mean_squared_error'])
    return model


clf1=KerasClassifier(build_fn=NeuN, verbose=1)
batch_size = [32, 64, 128, 256]
epochs = [10,11,12,13,14,15,16]
lr = [0.001,0.01,0.1,0.2]
search_spaces=dict(batch_size=batch_size,epochs=epochs,lr= lr)

# %%
def clf_grid_cv(clf,search_spaces):
    grid = GridSearchCV(estimator=clf, param_grid=search_spaces,cv=5, n_jobs=-1,scoring='neg_mean_squared_error')
    grid_result=grid.fit(X_train, y_train)
    
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    print('---------------------------------------------------------')
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("Accuracy : %f ( Std : %f) with: %r" % (mean, stdev, param))
    return grid_result

# %%
grid_result=clf_grid_cv(clf,search_spaces)
# Out:
# Epoch 1/16
# 831/831 [==============================] - 1s 1ms/step - loss: 238.7597 - mean_squared_error: 238.7597
# Epoch 2/16
# 831/831 [==============================] - 1s 1ms/step - loss: 187.9417 - mean_squared_error: 187.9417
# Epoch 3/16
# 831/831 [==============================] - 1s 1ms/step - loss: 182.4817 - mean_squared_error: 182.4817
# Epoch 4/16
# 831/831 [==============================] - 1s 1ms/step - loss: 180.1310 - mean_squared_error: 180.1310
# Epoch 5/16
# 831/831 [==============================] - 1s 1ms/step - loss: 178.1337 - mean_squared_error: 178.1337
# Epoch 6/16
# 831/831 [==============================] - 1s 1ms/step - loss: 175.5619 - mean_squared_error: 175.5619
# Epoch 7/16
# 831/831 [==============================] - 1s 1ms/step - loss: 174.2545 - mean_squared_error: 174.2545
# Epoch 8/16
# 831/831 [==============================] - 1s 1ms/step - loss: 172.9072 - mean_squared_error: 172.9072
# Epoch 9/16
# 831/831 [==============================] - 1s 1ms/step - loss: 171.2346 - mean_squared_error: 171.2346
# Epoch 10/16
# 831/831 [==============================] - 1s 1ms/step - loss: 170.2801 - mean_squared_error: 170.2801
# Epoch 11/16
# 831/831 [==============================] - 1s 1ms/step - loss: 169.7726 - mean_squared_error: 169.7726
# Epoch 12/16
# 831/831 [==============================] - 1s 1ms/step - loss: 168.1940 - mean_squared_error: 168.1940
# Epoch 13/16
# 831/831 [==============================] - 1s 1ms/step - loss: 165.9804 - mean_squared_error: 165.9804
# Epoch 14/16
# 831/831 [==============================] - 1s 1ms/step - loss: 165.3190 - mean_squared_error: 165.3190
# Epoch 15/16
# 831/831 [==============================] - 1s 1ms/step - loss: 163.4766 - mean_squared_error: 163.4766
# Epoch 16/16
# 831/831 [==============================] - 1s 1ms/step - loss: 162.3846 - mean_squared_error: 162.3846
# Best: -1803.652116 using {'batch_size': 64, 'epochs': 16}
# ---------------------------------------------------------
# Accuracy : -1803.657308 ( Std : 12.522663) with: {'batch_size': 32, 'epochs': 10}
# Accuracy : -1803.654128 ( Std : 12.524410) with: {'batch_size': 32, 'epochs': 11}
# Accuracy : -1803.652812 ( Std : 12.524489) with: {'batch_size': 32, 'epochs': 12}
# Accuracy : -1803.655257 ( Std : 12.525236) with: {'batch_size': 32, 'epochs': 13}
# Accuracy : -1803.654034 ( Std : 12.527262) with: {'batch_size': 32, 'epochs': 14}
# Accuracy : -1803.654919 ( Std : 12.524000) with: {'batch_size': 32, 'epochs': 15}
# Accuracy : -1803.658286 ( Std : 12.521658) with: {'batch_size': 32, 'epochs': 16}
# Accuracy : -1803.652247 ( Std : 12.524570) with: {'batch_size': 64, 'epochs': 10}
# Accuracy : -1803.652454 ( Std : 12.525330) with: {'batch_size': 64, 'epochs': 11}
# Accuracy : -1803.654674 ( Std : 12.524087) with: {'batch_size': 64, 'epochs': 12}
# Accuracy : -1803.655464 ( Std : 12.525108) with: {'batch_size': 64, 'epochs': 13}
# Accuracy : -1803.654825 ( Std : 12.522433) with: {'batch_size': 64, 'epochs': 14}
# Accuracy : -1803.654260 ( Std : 12.524748) with: {'batch_size': 64, 'epochs': 15}
# Accuracy : -1803.652116 ( Std : 12.525740) with: {'batch_size': 64, 'epochs': 16}
# Accuracy : -1803.653922 ( Std : 12.523815) with: {'batch_size': 128, 'epochs': 10}
# Accuracy : -1803.656461 ( Std : 12.521757) with: {'batch_size': 128, 'epochs': 11}
# Accuracy : -1803.655915 ( Std : 12.523392) with: {'batch_size': 128, 'epochs': 12}
# Accuracy : -1803.658737 ( Std : 12.524594) with: {'batch_size': 128, 'epochs': 13}
# Accuracy : -1803.654693 ( Std : 12.524357) with: {'batch_size': 128, 'epochs': 14}
# Accuracy : -1803.654241 ( Std : 12.523744) with: {'batch_size': 128, 'epochs': 15}
# Accuracy : -1803.657703 ( Std : 12.522679) with: {'batch_size': 128, 'epochs': 16}
# Accuracy : -1803.654617 ( Std : 12.523339) with: {'batch_size': 256, 'epochs': 10}
# Accuracy : -1803.654223 ( Std : 12.524830) with: {'batch_size': 256, 'epochs': 11}
# Accuracy : -1803.657345 ( Std : 12.522220) with: {'batch_size': 256, 'epochs': 12}
# Accuracy : -1803.655238 ( Std : 12.525395) with: {'batch_size': 256, 'epochs': 13}
# Accuracy : -1803.657326 ( Std : 12.521084) with: {'batch_size': 256, 'epochs': 14}
# Accuracy : -1803.656593 ( Std : 12.523040) with: {'batch_size': 256, 'epochs': 15}
# Accuracy : -1803.654730 ( Std : 12.524175) with: {'batch_size': 256, 'epochs': 16}

# %%
model = Sequential()
model.add(Input((input_nodes,)))
model.add(Dense(256, activation="relu"))
# model.add(Dropout(0.3, seed=0))
model.add(Dense(256, activation="relu"))
# model.add(Dropout(0.3, seed=1))
model.add(Dense(256, activation="relu"))
# model.add(Dropout(0.3, seed=2))
model.add(Dense(output_nodes, activation="linear"))

optimizer = keras.optimizers.Adam(lr=0.001)

model.compile(optimizer=optimizer,loss='mean_squared_error',metrics=['mean_squared_error'])

# %%
history1 = model.fit(X_train,
        y_train,
        batch_size=64,
        epochs=16,
        verbose=1,
        )
# Out:
# Epoch 1/16
# 831/831 [==============================] - 1s 2ms/step - loss: 241.0671 - mean_squared_error: 241.0671
# Epoch 2/16
# 831/831 [==============================] - 1s 1ms/step - loss: 187.5147 - mean_squared_error: 187.5147
# Epoch 3/16
# 831/831 [==============================] - 1s 2ms/step - loss: 182.6440 - mean_squared_error: 182.6440
# Epoch 4/16
# 831/831 [==============================] - 1s 2ms/step - loss: 180.3921 - mean_squared_error: 180.3921
# Epoch 5/16
# 831/831 [==============================] - 1s 1ms/step - loss: 177.6949 - mean_squared_error: 177.6949
# Epoch 6/16
# 831/831 [==============================] - 1s 1ms/step - loss: 176.3917 - mean_squared_error: 176.3917
# Epoch 7/16
# 831/831 [==============================] - 1s 1ms/step - loss: 173.9348 - mean_squared_error: 173.9348
# Epoch 8/16
# 831/831 [==============================] - 1s 1ms/step - loss: 172.4514 - mean_squared_error: 172.4514
# Epoch 9/16
# 831/831 [==============================] - 1s 1ms/step - loss: 170.7477 - mean_squared_error: 170.7477
# Epoch 10/16
# 831/831 [==============================] - 1s 1ms/step - loss: 169.8800 - mean_squared_error: 169.8800
# Epoch 11/16
# 831/831 [==============================] - 1s 1ms/step - loss: 168.2097 - mean_squared_error: 168.2097
# Epoch 12/16
# 831/831 [==============================] - 1s 1ms/step - loss: 167.1992 - mean_squared_error: 167.1992
# Epoch 13/16
# 831/831 [==============================] - 1s 1ms/step - loss: 166.0776 - mean_squared_error: 166.0776
# Epoch 14/16
# 831/831 [==============================] - 1s 1ms/step - loss: 164.3153 - mean_squared_error: 164.3153
# Epoch 15/16
# 831/831 [==============================] - 1s 1ms/step - loss: 163.0297 - mean_squared_error: 163.0297
# Epoch 16/16
# 831/831 [==============================] - 1s 1ms/step - loss: 161.9777 - mean_squared_error: 161.9777

# %%
y_pred1 = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred1)
rmse = math.sqrt(mean_squared_error(y_test, y_pred1))
print("MAE:",mae)
print("RMSE:",rmse)
# Out:
# MAE: 10.424702863290163
# RMSE: 13.307911293785631

# %%
y_pred2 = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred2)
rmse = math.sqrt(mean_squared_error(y_test, y_pred2))
print("MAE:",mae)
print("RMSE:",rmse)
# Out:
# MAE: 10.343353136561094
# RMSE: 13.211678012320391

# %% [markdown]
# ### Five Emotions

# %%
mood1 = pd.read_csv("lyrics_pred_class_lda.csv",index_col=0)
com = pd.concat([df,mood1],axis=1)
com = pd.concat([com, pd.get_dummies(com['classes'])], axis = 1)
com.drop(columns = ['classes'], inplace = True)
com.rename(columns={0:'neutral', 1:'happy', 2:'sad',3:'hate',4:'anger'}, inplace = True)

# %%
y_com = com['popularity'].copy()
X_com = com[acoustic_col+lyrics_col+['neutral', 'happy', 'sad', 'hate', 'anger']].copy()
scale_features1= X_com.drop(['explicit','mode_y','neutral', 'happy', 'sad', 'hate', 'anger'],axis=1).columns
X_train1,X_test1,y_train1,y_test1 = train_test_split(X_com, y_com,train_size=0.8,random_state=1234)

# %%
scaler = StandardScaler()
scaler.fit(X_train1[scale_features1])
X_train1[scale_features1]= scaler.transform(X_train1[scale_features1])
X_test1[scale_features1]= scaler.transform(X_test1[scale_features1])

# %%
input_nodes = X_train1.shape[1]
output_nodes = 1

# %%
model = Sequential()
model.add(Input((input_nodes,)))
model.add(Dense(256, activation="relu"))
# model.add(Dropout(0.3, seed=0))
model.add(Dense(256, activation="relu"))
# model.add(Dropout(0.3, seed=1))
model.add(Dense(256, activation="relu"))
# model.add(Dropout(0.3, seed=2))
model.add(Dense(output_nodes, activation="linear"))

optimizer = keras.optimizers.Adam(lr=0.001)

model.compile(optimizer=optimizer,loss='mean_squared_error',metrics=['mean_squared_error'])

# %%
X_train1 = np.asarray(X_train1).astype(np.float32)

# %%
history = model.fit(X_train1,
        y_train1,
        batch_size=128,
        epochs=15,
        verbose=1,
        )
# Out:
# Epoch 1/15
# 416/416 [==============================] - 1s 2ms/step - loss: 272.5897 - mean_squared_error: 272.5897
# Epoch 2/15
# 416/416 [==============================] - 1s 2ms/step - loss: 188.2134 - mean_squared_error: 188.2134
# Epoch 3/15
# 416/416 [==============================] - 1s 2ms/step - loss: 182.5534 - mean_squared_error: 182.5534
# Epoch 4/15
# 416/416 [==============================] - 1s 2ms/step - loss: 180.3431 - mean_squared_error: 180.3431
# Epoch 5/15
# 416/416 [==============================] - 1s 2ms/step - loss: 177.4745 - mean_squared_error: 177.4745
# Epoch 6/15
# 416/416 [==============================] - 1s 2ms/step - loss: 175.6899 - mean_squared_error: 175.6899
# Epoch 7/15
# 416/416 [==============================] - 1s 2ms/step - loss: 173.9592 - mean_squared_error: 173.9592
# Epoch 8/15
# 416/416 [==============================] - 1s 2ms/step - loss: 172.5640 - mean_squared_error: 172.5640
# Epoch 9/15
# 416/416 [==============================] - 1s 2ms/step - loss: 172.3751 - mean_squared_error: 172.3751
# Epoch 10/15
# 416/416 [==============================] - 1s 2ms/step - loss: 170.4117 - mean_squared_error: 170.4117
# Epoch 11/15
# 416/416 [==============================] - 1s 2ms/step - loss: 169.6497 - mean_squared_error: 169.6497
# Epoch 12/15
# 416/416 [==============================] - 1s 2ms/step - loss: 167.8266 - mean_squared_error: 167.8266
# Epoch 13/15
# 416/416 [==============================] - 1s 2ms/step - loss: 166.1658 - mean_squared_error: 166.1658
# Epoch 14/15
# 416/416 [==============================] - 1s 2ms/step - loss: 165.3503 - mean_squared_error: 165.3503
# Epoch 15/15
# 416/416 [==============================] - 1s 2ms/step - loss: 163.9411 - mean_squared_error: 163.9411

# %%
y_pr = model.predict(X_test1)
mae = mean_absolute_error(y_test1, y_pr)
rmse = math.sqrt(mean_squared_error(y_test1, y_pr))
print("MAE:",mae)
print("RMSE:",rmse)
# Out:
# MAE: 10.444169214123008
# RMSE: 13.244049403899474

# %%
def clf_grid_cv1(clf,search_spaces):
    grid = GridSearchCV(estimator=clf, param_grid=search_spaces,cv=5, n_jobs=-1,scoring='neg_mean_squared_error')
    grid_result=grid.fit(X_train1, y_train1)
    
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    print('---------------------------------------------------------')
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("Accuracy : %f ( Std : %f) with: %r" % (mean, stdev, param))
    return grid_result

# %%
grid_result1=clf_grid_cv1(clf,search_spaces)

# %%
history = model.fit(X_train1,
        y_train1,
        batch_size=64,
        epochs=14,
        verbose=1
        )
# Out:
# Epoch 1/14
# 831/831 [==============================] - 1s 1ms/step - loss: 3148.8713 - mean_squared_error: 3148.8713
# Epoch 2/14
# 831/831 [==============================] - 1s 1ms/step - loss: 331.4590 - mean_squared_error: 331.4590
# Epoch 3/14
# 831/831 [==============================] - 1s 2ms/step - loss: 324.1710 - mean_squared_error: 324.1710
# Epoch 4/14
# 831/831 [==============================] - 1s 2ms/step - loss: 324.2531 - mean_squared_error: 324.2531
# Epoch 5/14
# 831/831 [==============================] - 1s 2ms/step - loss: 324.8105 - mean_squared_error: 324.8105
# Epoch 6/14
# 831/831 [==============================] - 1s 2ms/step - loss: 323.8185 - mean_squared_error: 323.8185
# Epoch 7/14
# 831/831 [==============================] - 1s 2ms/step - loss: 323.8322 - mean_squared_error: 323.8322
# Epoch 8/14
# 831/831 [==============================] - 1s 2ms/step - loss: 323.3792 - mean_squared_error: 323.3792
# Epoch 9/14
# 831/831 [==============================] - 1s 1ms/step - loss: 323.5934 - mean_squared_error: 323.5934
# Epoch 10/14
# 831/831 [==============================] - 1s 2ms/step - loss: 323.7039 - mean_squared_error: 323.7039
# Epoch 11/14
# 831/831 [==============================] - 2s 2ms/step - loss: 323.5826 - mean_squared_error: 323.5826
# Epoch 12/14
# 831/831 [==============================] - 2s 2ms/step - loss: 323.2761 - mean_squared_error: 323.2761
# Epoch 13/14
# 831/831 [==============================] - 1s 2ms/step - loss: 323.5927 - mean_squared_error: 323.5927
# Epoch 14/14
# 831/831 [==============================] - 1s 2ms/step - loss: 322.9702 - mean_squared_error: 322.9702

# %%
y_pr = model.predict(X_test1)
mae = mean_absolute_error(y_test1, y_pr)
rmse = math.sqrt(mean_squared_error(y_test1, y_pr))
print("MAE:",mae)
print("RMSE:",rmse)
# Out:
# MAE: 10.359623552436044
# RMSE: 13.201788366934265
